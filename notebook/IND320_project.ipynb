# %% [markdown]
# # Welcome to my IND320 Jupyter notebook

# %% [markdown]
# ## Reading the supplied CSV file using Pandas and printing its contents in a relevant way.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../data/open-meteo-subset.csv")
df.head()
# Out:
#                time  temperature_2m (°C)  precipitation (mm)  \
# 0  2020-01-01T00:00                 -2.2                 0.1
# 1  2020-01-01T01:00                 -2.2                 0.0
# 2  2020-01-01T02:00                 -2.3                 0.0
# 3  2020-01-01T03:00                 -2.3                 0.0
# 4  2020-01-01T04:00                 -2.7                 0.0
#
#    wind_speed_10m (m/s)  wind_gusts_10m (m/s)  wind_direction_10m (°)
# 0                   9.6                  21.3                     284
# 1                  10.6                  23.0                     282
# 2                  11.0                  23.5                     284
# 3                  10.6                  23.3                     284
# 4                  10.6                  22.8                     284

# %% [markdown]
# ### I showed here all the columns

# %%
for i, col in enumerate(df.columns):
    print(f"{i}: {col}")
# Out:
# 0: time
# 1: temperature_2m (°C)
# 2: precipitation (mm)
# 3: wind_speed_10m (m/s)
# 4: wind_gusts_10m (m/s)
# 5: wind_direction_10m (°)

# %% [markdown]
# ## I plot each column separately.

# %%
for col in df.columns[1:]:  # without the "time" column
    df.plot(x="time", y=col, title=col)
    plt.show()

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# ## Ploting all columns together.
